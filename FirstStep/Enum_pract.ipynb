# %%
from enum import Enum 

class Member(str,Enum):
    ALEX = "alex"
    JAMES = "james"


print(type(Member.ALEX.value))
# Out:
# <class 'str'>

# %%
from collections import Counter
f =[1,1,1,2,2,3]
count = 0
freq=Counter(f)
for k in freq.values():
    if k >2:
        count+=1
print(f"the frequenncy of {len(f)-count}")
# Out:
# the frequenncy of 5
